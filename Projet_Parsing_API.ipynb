# %%
# On récupère tous les résultats de l'API concernant la partie Film
import requests
import json
response = requests.get('https://ghibliapi.herokuapp.com/films/').text
response_info = json.loads(response)
response_info
# Out:
# [{'id': '2baf70d1-42bb-4437-b551-e5fed5a87abe',
#   'title': 'Castle in the Sky',
#   'original_title': '天空の城ラピュタ',
#   'original_title_romanised': 'Tenkū no shiro Rapyuta',
#   'description': "The orphan Sheeta inherited a mysterious crystal that links her to the mythical sky-kingdom of Laputa. With the help of resourceful Pazu and a rollicking band of sky pirates, she makes her way to the ruins of the once-great civilization. Sheeta and Pazu must outwit the evil Muska, who plans to use Laputa's science to make himself ruler of the world.",
#   'director': 'Hayao Miyazaki',
#   'producer': 'Isao Takahata',
#   'release_date': '1986',
#   'running_time': '124',
#   'rt_score': '95',
#   'people': ['https://ghibliapi.herokuapp.com/people/'],
#   'species': ['https://ghibliapi.herokuapp.com/species/af3910a6-429f-4c74-9ad5-dfe1c4aa04f2'],
#   'locations': ['https://ghibliapi.herokuapp.com/locations/'],
#   'vehicles': ['https://ghibliapi.herokuapp.com/vehicles/'],
# ...

# %%
# On affiche les informations souhaitées pour tous les films de l'API.
import requests
import json
response = requests.get('https://ghibliapi.herokuapp.com/films/').text
response_info = json.loads(response)
# response_info

film_list = []
for film_info in response_info:
    film_list.append([film_info['title'], film_info['director'], film_info['producer'], film_info['release_date']])
film_list
# Out:
# [['Castle in the Sky', 'Hayao Miyazaki', 'Isao Takahata', '1986'],
#  ['Grave of the Fireflies', 'Isao Takahata', 'Toru Hara', '1988'],
#  ['My Neighbor Totoro', 'Hayao Miyazaki', 'Hayao Miyazaki', '1988'],
#  ["Kiki's Delivery Service", 'Hayao Miyazaki', 'Hayao Miyazaki', '1989'],
#  ['Only Yesterday', 'Isao Takahata', 'Toshio Suzuki', '1991'],
#  ['Porco Rosso', 'Hayao Miyazaki', 'Toshio Suzuki', '1992'],
#  ['Pom Poko', 'Isao Takahata', 'Toshio Suzuki', '1994'],
#  ['Whisper of the Heart', 'Yoshifumi Kondō', 'Toshio Suzuki', '1995'],
#  ['Princess Mononoke', 'Hayao Miyazaki', 'Toshio Suzuki', '1997'],
#  ['My Neighbors the Yamadas', 'Isao Takahata', 'Toshio Suzuki', '1999'],
#  ['Spirited Away', 'Hayao Miyazaki', 'Toshio Suzuki', '2001'],
#  ['The Cat Returns', 'Hiroyuki Morita', 'Toshio Suzuki', '2002'],
#  ["Howl's Moving Castle", 'Hayao Miyazaki', 'Toshio Suzuki', '2004'],
#  ['Tales from Earthsea', 'Gorō Miyazaki', 'Toshio Suzuki', '2006'],
# ...

# %%
# Création et complétion du fichier CSV.
import requests
import json
import csv
response = requests.get('https://ghibliapi.herokuapp.com/films/').text
response_info = json.loads(response)
# response_info

film_list = []

nomFichierCSV = input("Saisissez le nom du fichier : ")

f = codecs.open(nomFichierCSV+'.csv', mode='w', encoding='iso-8859-1')
f.close()

with open(nomFichierCSV+'.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ',quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for film_info in response_info:
        spamwriter.writerow({'Titre : ' + film_info['title'] + ' / Directeur : ' + film_info['director']  + ' / Producteur : ' + film_info['producer']  + ' / Date de sortie : ' + film_info['release_date']})
# Out:
# Saisissez le nom du fichier :  FilmsGhibli_AvecDirecteur
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-144-18d64d6f215b> in <module>
#      17     spamwriter = csv.writer(csvfile, delimiter=' ',quotechar='|', quoting=csv.QUOTE_MINIMAL)
#      18     for film_info in response_info:
# ---> 19         spamwriter.writerow({'Titre : ' + film_info['title'] + ' / Directeur : ' + film_info['director']  + ' / Producteur : ' + film_info['producer']  + ' / Date de sortie : ' + film_info['release_date']})
#
# ~\anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# ...

# %%
# On lit les informations présentes dans le fichier CSV voulu. 
import requests
import json
import csv
response = requests.get('https://ghibliapi.herokuapp.com/films/').text
response_info = json.loads(response)
# response_info

film_list = []

nomFichierCSV = input("Saisissez le nom du fichier CSV à afficher (sans le .csv) : ")

with open(nomFichierCSV + '.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in spamreader:
        print(', '.join(row))
# Out:
# Saisissez le nom du fichier CSV à afficher (sans le .csv) :  ghibli
# Titre : Castle in the Sky / Directeur : Hayao Miyazaki / Producteur : Isao Takahata / Date de sortie : 1986
# Titre : Grave of the Fireflies / Directeur : Isao Takahata / Producteur : Toru Hara / Date de sortie : 1988
# Titre : My Neighbor Totoro / Directeur : Hayao Miyazaki / Producteur : Hayao Miyazaki / Date de sortie : 1988
# Titre : Kiki's Delivery Service / Directeur : Hayao Miyazaki / Producteur : Hayao Miyazaki / Date de sortie : 1989
# Titre : Only Yesterday / Directeur : Isao Takahata / Producteur : Toshio Suzuki / Date de sortie : 1991
# Titre : Porco Rosso / Directeur : Hayao Miyazaki / Producteur : Toshio Suzuki / Date de sortie : 1992
# Titre : Pom Poko / Directeur : Isao Takahata / Producteur : Toshio Suzuki / Date de sortie : 1994
